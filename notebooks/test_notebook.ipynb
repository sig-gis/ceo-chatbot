# %%
from src.a_b import a_b

result = a_b()
print(result)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.a_b import a_b
#       3 result = a_b()
#       4 print(result)
#
# ModuleNotFoundError: No module named 'src'

# %% [markdown]
# ^ Does not work with regular uv .venv
#
# tried installing a ipython project kernel:
#
# `uv run python -m ipykernel install --user --name=ceo-chatbot --display-name="Python (ceo-chatbot)"`
#
# then selecting that kernel

# %% [markdown]
# Gemini also suggesting some funny things like what you see at the bottom of my modified `pyproject.toml` then doing `uv pip install -e .` seemingly to install our project as editable package and to give instructions to always find `/src`.. also did not work

# %% [markdown]
# Ultimately, this is the simplest way to "just fix it" but is a per-notebook requirement. As i don't see notebooks as a long-lived permanent thing, i think i'll just do this if i find the inspiration to develop using .ipynb

# %%
import sys
sys.path.append("../")

from src.a_b import a_b

result = a_b()
print(result)
# Out:
# [[100 102 104 106 108 110 112 114 116 118]
#  [120 122 124 126 128 130 132 134 136 138]
#  [140 142 144 146 148 150 152 154 156 158]
#  [160 162 164 166 168 170 172 174 176 178]
#  [180 182 184 186 188 190 192 194 196 198]
#  [200 202 204 206 208 210 212 214 216 218]
#  [220 222 224 226 228 230 232 234 236 238]
#  [240 242 244 246 248 250 252 254 256 258]
#  [260 262 264 266 268 270 272 274 276 278]
#  [280 282 284 286 288 290 292 294 296 298]]
